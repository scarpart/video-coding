# %% [markdown]
# # Visualizing the data gathered from the PSNR/BitRate Parser and the BDrate computation function from BDrate.py (by Shengbin Meng) implemented on main.py

# %% [markdown]
# ### Importing the relevant libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ### Loading contents from the JSON config file

# %%
file_cfg = open('configs.json')
configs = json.load(file_cfg)
file_cfg.close()

# %% [markdown]
# ### Initializing pandas DataFrame with the resulting information

# %%
df = pd.read_csv("~/VC/video-coding/results.csv") 
vtmdf = df.iloc[:16, :]
vvencdf = df.iloc[16:, :]

# %%
vtmdf
# Out:
#    encoder               v     video_res  num_frames  qsize   bit_rate  \
# 0      VTM  BasketballPass    416x240_50           1     22    7208.80
# 1      VTM  BasketballPass    416x240_50           1     27    4422.00
# 2      VTM  BasketballPass    416x240_50           1     32    2642.00
# 3      VTM  BasketballPass    416x240_50           1     37    1481.60
# 4      VTM          Cactus  1920x1080_50           1     22  109918.40
# 5      VTM          Cactus  1920x1080_50           1     27   57384.40
# 6      VTM          Cactus  1920x1080_50           1     32   33016.80
# 7      VTM          Cactus  1920x1080_50           1     37   18448.40
# 8      VTM     RaceHorsesC    832x480_30           1     22   18996.96
# 9      VTM     RaceHorsesC    832x480_30           1     27   11990.64
# 10     VTM     RaceHorsesC    832x480_30           1     32    7383.36
# 11     VTM     RaceHorsesC    832x480_30           1     37    4144.80
# 12     VTM      FourPeople   1280x720_60           1     22   35899.68
# 13     VTM      FourPeople   1280x720_60           1     27   22793.76
# 14     VTM      FourPeople   1280x720_60           1     32   14539.68
# 15     VTM      FourPeople   1280x720_60           1     37    9036.96
#
#        psnr  optional_settings   total_time
# 0   46.0284                NaN       57.750
# 1   42.7948                NaN       59.854
# 2   39.6985                NaN       46.542
# 3   36.4891                NaN       30.230
# 4   41.0578                NaN     1254.789
# 5   39.3308                NaN      792.388
# 6   37.8478                NaN      372.983
# 7   35.9316                NaN      254.578
# 8   42.6351                NaN      158.783
# 9   39.9670                NaN      138.467
# 10  37.2959                NaN      121.948
# 11  34.3350                NaN       93.245
# 12  46.2077                NaN      278.718
# 13  44.5357                NaN      189.777
# 14  42.4462                NaN      131.356
# 15  39.7978                NaN      101.921

# %%
vvencdf
# Out:
#    encoder               v     video_res  num_frames  qsize   bit_rate  \
# 16   vvenc  BasketballPass    416x240_50           1     22  330415.68
# 17   vvenc  BasketballPass    416x240_50           1     27  216385.44
# 18   vvenc  BasketballPass    416x240_50           1     32  135668.16
# 19   vvenc  BasketballPass    416x240_50           1     37   81566.88
# 20   vvenc          Cactus  1920x1080_50           1     22  209250.24
# 21   vvenc          Cactus  1920x1080_50           1     27   82126.08
# 22   vvenc          Cactus  1920x1080_50           1     32   41939.52
# 23   vvenc          Cactus  1920x1080_50           1     37   22675.68
# 24   vvenc     RaceHorsesC    832x480_30           1     22  434564.64
# 25   vvenc     RaceHorsesC    832x480_30           1     27  303369.12
# 26   vvenc     RaceHorsesC    832x480_30           1     32  203547.84
# 27   vvenc     RaceHorsesC    832x480_30           1     37  126757.92
# 28   vvenc      FourPeople   1280x720_60           1     22  223996.32
# 29   vvenc      FourPeople   1280x720_60           1     27  132309.60
# 30   vvenc      FourPeople   1280x720_60           1     32   84865.44
# 31   vvenc      FourPeople   1280x720_60           1     37   50704.32
#
#        psnr                    optional_settings   total_time
# 16  44.7611  --threads 1 --qpa 0 --preset slower      781.241
# 17  40.2597  --threads 1 --qpa 0 --preset slower      659.286
# 18  36.2792  --threads 1 --qpa 0 --preset slower      461.607
# 19  32.6449  --threads 1 --qpa 0 --preset slower      365.106
# 20  44.5314  --threads 1 --qpa 0 --preset slower      534.845
# 21  40.2503  --threads 1 --qpa 0 --preset slower      369.338
# 22  38.2136  --threads 1 --qpa 0 --preset slower      189.016
# 23  36.0920  --threads 1 --qpa 0 --preset slower      120.949
# 24  45.8608  --threads 1 --qpa 0 --preset slower      688.829
# 25  41.2510  --threads 1 --qpa 0 --preset slower      706.816
# 26  37.0423  --threads 1 --qpa 0 --preset slower      671.967
# 27  32.9142  --threads 1 --qpa 0 --preset slower      723.312
# 28  45.8006  --threads 1 --qpa 0 --preset slower      712.957
# 29  41.5303  --threads 1 --qpa 0 --preset slower      431.889
# 30  38.0312  --threads 1 --qpa 0 --preset slower      301.897
# 31  34.4101  --threads 1 --qpa 0 --preset slower      225.035

# %% [markdown]
# ### Visualizing the VTM results

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5))
sns.barplot(data=vtmdf, x='v', y='psnr', hue='qsize', ax=axes[0]).set(title='VTM Test Run: Correlation Between Quantization Parameters and PSNR/BitRate', xlabel='')
sns.barplot(data=vtmdf, x='v', y='bit_rate', hue='qsize', ax=axes[1]).set(xlabel='Videos')
# Out:
# [Text(0.5, 0, 'Videos')]

# %% [markdown]
# ### Visualizing the vvenc results

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5))
sns.barplot(data=vvencdf, x='v', y='psnr', hue='qsize', ax=axes[0]).set(title='VVenC Test Run: Correlation Between Quantization Parameters and PSNR/BitRate', xlabel='')
sns.barplot(data=vvencdf, x='v', y='bit_rate', hue='qsize', ax=axes[1]).set(xlabel='Videos')
# Out:
# [Text(0.5, 0, 'Videos')]

# %% [markdown]
# ### Visualizing the average difference (BD-Rate) between VTM and vvenc

# %%
from BDrate import BD_RATE

# Initializing useful data structures
avg_diffs = []
labels = []

for v in configs['videos']:
    # Calculating the BD-Rate
    index_div = v.index("_")
    v_name = v[:index_div]
    videodf = df[df['v'] == v_name]
    r1 = videodf['bit_rate'].iloc[:4]
    r2 = videodf['bit_rate'].iloc[4:]
    psnr1 = videodf['psnr'].iloc[:4]
    psnr2 = videodf['psnr'].iloc[4:]
    avg_diffs.append(BD_RATE(r1, psnr1, r2, psnr2))
    
    # Getting the names of the videos, without the resolution
    div_index = v.index("_")
    labels.append(v[:div_index])

# Plotting the graph
plt.figure(figsize=(15,5))
sns.set_style('dark')
sns.barplot(y=avg_diffs, x=labels, palette=['b']).set(ylabel='Average difference', title='BD-Rate: Average Difference Between VTM and VVenC for Four Sequences', xlabel='Sequences')
plt.show()

# %% [markdown]
# ### Visualizing the difference between VTM and vvenc by means of a BitRate vs PSNR scatter plot

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10))
fig.suptitle('PSNRxBitRate per Sequence: VTM and VVenC Compared', fontsize=16)

# first sequence
firstvtm = vtmdf[:4]
firstvvenc = vvencdf[:4]
axes[0][0].plot(firstvtm.bit_rate, firstvtm.psnr, linestyle='--', marker='x', c='b', label='VTM')
axes[0][0].plot(firstvvenc.bit_rate, firstvvenc.psnr, linestyle='--', marker='o', c='r')
axes[0][0].set_title('BasketballPass')
axes[0][0].legend(['VTM', 'vvenc'])

# second sequence
secondvtm = vtmdf[4:8]
secondvvenc = vvencdf[4:8]
axes[0][1].plot(secondvtm.bit_rate, secondvtm.psnr, linestyle='--', marker='x', c='b')
axes[0][1].plot(secondvvenc.bit_rate, secondvvenc.psnr, linestyle='--', marker='o', c='r')
axes[0][1].set_title('Cactus')
axes[0][1].legend(['VTM', 'vvenc'])

# third sequence
thirdvtm = vtmdf[8:12]
thirdvvenc = vvencdf[8:12]
axes[1][0].plot(thirdvtm.bit_rate, thirdvtm.psnr, linestyle='--', marker='x', c='b')
axes[1][0].plot(thirdvvenc.bit_rate, thirdvvenc.psnr, linestyle='--', marker='o', c='r')
axes[1][0].set_title('RaceHorsesC')
axes[1][0].legend(['VTM', 'vvenc'])

# fourth sequence
fourthvtm = vtmdf[12:16]
fourthvvenc = vvencdf[12:16]
axes[1][1].plot(fourthvtm.bit_rate, fourthvtm.psnr, linestyle='--', marker='x', c='b')
axes[1][1].plot(fourthvvenc.bit_rate, fourthvvenc.psnr, linestyle='--', marker='o', c='r')
axes[1][1].set_title('FourPeople')
axes[1][1].legend(['VTM', 'vvenc'])

plt.savefig('./graphs/PSNRxBitRate by Sequence')
