# %% [markdown]
# # Visualizing the data gathered from the PSNR/BitRate Parser and the BDrate computation function from BDrate.py (by Shengbin Meng) implemented on main.py

# %% [markdown]
# ### Importing the relevant libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ### Loading contents from the JSON config file

# %%
file_cfg = open('configs.json')
configs = json.load(file_cfg)
file_cfg.close()

# %% [markdown]
# ### Initializing pandas DataFrame with the resulting information

# %%
df = pd.read_csv("/home/arttington/VC/video-coding/results.csv") # it's different here because I'm doing this on another computer
vtmdf = df.iloc[:16, :]
vvencdf = df.iloc[16:, :]

# %%
vtmdf
# Out:
#    encoder                              v     video_res  num_frames  qsize  \
# 0      VTM  BasketballPass_416x240_50.yuv    416x240_50           1     22
# 1      VTM  BasketballPass_416x240_50.yuv    416x240_50           1     27
# 2      VTM  BasketballPass_416x240_50.yuv    416x240_50           1     32
# 3      VTM  BasketballPass_416x240_50.yuv    416x240_50           1     37
# 4      VTM        Cactus_1920x1080_50.yuv  1920x1080_50           1     22
# 5      VTM        Cactus_1920x1080_50.yuv  1920x1080_50           1     27
# 6      VTM        Cactus_1920x1080_50.yuv  1920x1080_50           1     32
# 7      VTM        Cactus_1920x1080_50.yuv  1920x1080_50           1     37
# 8      VTM     RaceHorsesC_832x480_30.yuv    832x480_30           1     22
# 9      VTM     RaceHorsesC_832x480_30.yuv    832x480_30           1     27
# 10     VTM     RaceHorsesC_832x480_30.yuv    832x480_30           1     32
# 11     VTM     RaceHorsesC_832x480_30.yuv    832x480_30           1     37
# 12     VTM     FourPeople_1280x720_60.yuv   1280x720_60           1     22
# 13     VTM     FourPeople_1280x720_60.yuv   1280x720_60           1     27
# 14     VTM     FourPeople_1280x720_60.yuv   1280x720_60           1     32
# 15     VTM     FourPeople_1280x720_60.yuv   1280x720_60           1     37
#
#      bit_rate     psnr   optional_settings
# 0     7208.80  46.0284                 NaN
# 1     4422.00  42.7948                 NaN
# 2     2642.00  39.6985                 NaN
# 3     1481.60  36.4891                 NaN
# 4   109918.40  41.0578                 NaN
# 5    57384.40  39.3308                 NaN
# 6    33016.80  37.8478                 NaN
# 7    18448.40  35.9316                 NaN
# 8    18996.96  42.6351                 NaN
# 9    11990.64  39.9670                 NaN
# 10    7383.36  37.2959                 NaN
# 11    4144.80  34.3350                 NaN
# 12   35899.68  46.2077                 NaN
# 13   22793.76  44.5357                 NaN
# 14   14539.68  42.4462                 NaN
# 15    9036.96  39.7978                 NaN

# %%
vvencdf
# Out:
#    encoder                              v     video_res  num_frames  qsize  \
# 16   vvenc  BasketballPass_416x240_50.yuv    416x240_50           1     22
# 17   vvenc  BasketballPass_416x240_50.yuv    416x240_50           1     27
# 18   vvenc  BasketballPass_416x240_50.yuv    416x240_50           1     32
# 19   vvenc  BasketballPass_416x240_50.yuv    416x240_50           1     37
# 20   vvenc        Cactus_1920x1080_50.yuv  1920x1080_50           1     22
# 21   vvenc        Cactus_1920x1080_50.yuv  1920x1080_50           1     27
# 22   vvenc        Cactus_1920x1080_50.yuv  1920x1080_50           1     32
# 23   vvenc        Cactus_1920x1080_50.yuv  1920x1080_50           1     37
# 24   vvenc     RaceHorsesC_832x480_30.yuv    832x480_30           1     22
# 25   vvenc     RaceHorsesC_832x480_30.yuv    832x480_30           1     27
# 26   vvenc     RaceHorsesC_832x480_30.yuv    832x480_30           1     32
# 27   vvenc     RaceHorsesC_832x480_30.yuv    832x480_30           1     37
# 28   vvenc     FourPeople_1280x720_60.yuv   1280x720_60           1     22
# 29   vvenc     FourPeople_1280x720_60.yuv   1280x720_60           1     27
# 30   vvenc     FourPeople_1280x720_60.yuv   1280x720_60           1     32
# 31   vvenc     FourPeople_1280x720_60.yuv   1280x720_60           1     37
#
#      bit_rate     psnr   optional_settings
# 16  220989.12  40.0051                 NaN
# 17  139727.52  35.9917                 NaN
# 18   84527.04  32.2956                 NaN
# 19   46397.76  28.7382                 NaN
# 20  262509.60  45.9383                 NaN
# 21  124326.72  41.4512                 NaN
# 22   51093.12  38.6500                 NaN
# 23   26927.04  36.5373                 NaN
# 24  272751.36  39.5888                 NaN
# 25  179684.64  35.3453                 NaN
# 26  109981.44  31.3451                 NaN
# 27   58925.76  27.6069                 NaN
# 28  154560.48  41.2001                 NaN
# 29   88731.36  36.6550                 NaN
# 30   50972.16  32.9654                 NaN
# 31   26417.28  29.5221                 NaN

# %% [markdown]
# ### Visualizing the VTM results

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5))
sns.barplot(data=vtmdf, x='v', y='psnr', hue='qsize', ax=axes[0]).set(title='VTM Test Run: Correlation Between Quantization Parameters and PSNR/BitRate', xlabel='')
sns.barplot(data=vtmdf, x='v', y='bit_rate', hue='qsize', ax=axes[1]).set(xlabel='Videos')
# Out:
# [Text(0.5, 0, 'Videos')]

# %% [markdown]
# ### Visualizing the vvenc results

# %%
fig, axes = plt.subplots(2, 1, figsize=(15,5))
sns.barplot(data=vvencdf, x='v', y='psnr', hue='qsize', ax=axes[0]).set(title='VVenC Test Run: Correlation Between Quantization Parameters and PSNR/BitRate', xlabel='')
sns.barplot(data=vvencdf, x='v', y='bit_rate', hue='qsize', ax=axes[1]).set(xlabel='Videos')
# Out:
# [Text(0.5, 0, 'Videos')]

# %% [markdown]
# ### Visualizing the average difference (BD-Rate) between VTM and vvenc

# %%
from BDrate import BD_RATE

# Initializing useful data structures
avg_diffs = []
labels = []

for v in configs['videos']:
    # Calculating the BD-Rate
    videodf = df[df['v'] == v]
    r1 = videodf['bit_rate'].iloc[:4]
    r2 = videodf['bit_rate'].iloc[4:]
    psnr1 = videodf['psnr'].iloc[:4]
    psnr2 = videodf['psnr'].iloc[4:]
    avg_diffs.append(BD_RATE(r1, psnr1, r2, psnr2))
    
    # Getting the names of the videos, without the resolution
    div_index = v.index("_")
    labels.append(v[:div_index])

# Plotting the graph
plt.figure(figsize=(15,5))
sns.set_style('dark')
sns.lineplot(y=avg_diffs, x=labels, palette=['b']).set(ylabel='Average difference', title='BD-Rate: Average Difference Between VTM and VVenC for Four Sequences', xlabel='Sequences')
plt.show()

# %% [markdown]
# ### Visualizing the difference between VTM and vvenc by means of a BitRate vs PSNR scatter plot

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10))
fig.suptitle('PSNRxBitRate per Sequence: VTM and VVenC Compared', fontsize=16)

# first sequence
firstvtm = vtmdf[:4]
firstvvenc = vvencdf[:4]
axes[0][0].plot(firstvtm.bit_rate, firstvtm.psnr, linestyle='--', marker='x', c='b', label='VTM')
axes[0][0].plot(firstvvenc.bit_rate, firstvvenc.psnr, linestyle='--', marker='o', c='r')
axes[0][0].set_title('BasketballPass')
axes[0][0].legend(['vvenc', 'VTM'])

# second sequence
firstvtm = vtmdf[4:8]
firstvvenc = vvencdf[4:8]
axes[0][1].plot(firstvtm.bit_rate, firstvtm.psnr, linestyle='--', marker='x', c='b')
axes[0][1].plot(firstvvenc.bit_rate, firstvvenc.psnr, linestyle='--', marker='o', c='r')
axes[0][1].set_title('Cactus')
axes[0][1].legend(['vvenc', 'VTM'])

# third sequence
firstvtm = vtmdf[8:12]
firstvvenc = vvencdf[8:12]
axes[1][0].plot(firstvtm.bit_rate, firstvtm.psnr, linestyle='--', marker='x', c='b')
axes[1][0].plot(firstvvenc.bit_rate, firstvvenc.psnr, linestyle='--', marker='o', c='r')
axes[1][0].set_title('RaceHorsesC')
axes[1][0].legend(['vvenc', 'VTM'])

# fourth sequence
firstvtm = vtmdf[12:16]
firstvvenc = vvencdf[12:16]
axes[1][1].plot(firstvtm.bit_rate, firstvtm.psnr, linestyle='--', marker='x', c='b')
axes[1][1].plot(firstvvenc.bit_rate, firstvvenc.psnr, linestyle='--', marker='o', c='r')
axes[1][1].set_title('FourPeople')
axes[1][1].legend(['vvenc', 'VTM'])

plt.legend()
plt.savefig('./graphs/PSNRxBitRate by Sequence')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/arttington/VC/video-coding/visualizing_data.ipynb Cell 17' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/home/arttington/VC/video-coding/visualizing_data.ipynb#ch0000016?line=4'>5</a> firstvtm = vtmdf[:4]
#       <a href='vscode-notebook-cell:/home/arttington/VC/video-coding/visualizing_data.ipynb#ch0000016?line=5'>6</a> firstvvenc = vvencdf[:4]
# ----> <a href='vscode-notebook-cell:/home/arttington/VC/video-coding/visualizing_data.ipynb#ch0000016?line=6'>7</a> axes[0][0].plot(firstvtm.bit_rate, firstvtm.pnsr, linestyle='--', marker='x', c='b', label='VTM')
#       <a href='vscode-notebook-cell:/home/arttington/VC/video-coding/visualizing_data.ipynb#ch0000016?line=7'>8</a> axes[0][0].plot(firstvvenc.bit_rate, firstvvenc.pnsr, linestyle='--', marker='o', c='r')
#       <a href='vscode-notebook-cell:/home/arttington/VC/video-coding/visualizing_data.ipynb#ch0000016?line=8'>9</a> axes[0][0].set_title('BasketballPass')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pnsr'
